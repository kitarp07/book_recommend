# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/DELL/Desktop/bookrecommend/books+authors+genres2.csv", index_col=0)
data
# Out:
#                                               title  ratings_count  author_id  \
# book_id
# 9758764                               Then Came You          36849       9212
# 28953953                       The Littlest Bigfoot            954       9212
# 14758                                  In Her Shoes         169410       9212
# 13809813                                       Swim           2812       9212
# 2160448                                 Good in Bed            212       9212
# ...                                             ...            ...        ...
# 17339959                  Talker 25 (Talker 25, #1)            387    6925229
# 25582830  Beetle Boy (The Battle of the Beetles #1)            457   14010953
# 85729                                       Noa Noa            281      49016
# 34447000                               La più amata            250    4599427
# 831792                         My Name is Seepeetza            255     432802
#
# ...

# %%
df = data.head(50)
df
# Out:
#                                                       title  ratings_count  \
# book_id
# 9758764                                       Then Came You          36849
# 28953953                               The Littlest Bigfoot            954
# 14758                                          In Her Shoes         169410
# 13809813                                               Swim           2812
# 2160448                                         Good in Bed            212
# 25205367                                    Who Do You Love            824
# 18223657                    Good Men (Cannie Shapiro, #0.5)            474
# 14748                      Good in Bed (Cannie Shapiro, #1)         251303
# 16130440  Hungry Heart: Adventures in Life, Love, and Wr...           3781
# 18599487                    Good Men (Cannie Shapiro, #0.5)            500
# 12987995                                The Next Best Thing            904
# ...

# %%
import pickle

pickle.dump(df, open('temp_df.pkl', 'wb'))

# %%
author_list = [
    "J.R.R. Tolkien", "George R.R. Martin", "J.K. Rowling", "Brandon Sanderson",
    "Patrick Rothfuss", "Neil Gaiman", "Terry Pratchett", "Ursula K. Le Guin",
    "Robin Hobb", "N.K. Jemisin", "Agatha Christie", "Gillian Flynn",
    "James Patterson", "Paula Hawkins", "Lee Child", "Tana French",
    "Harlan Coben", "Raymond Chandler", "Michael Connelly", "Louise Penny",
    "Isaac Asimov", "Philip K. Dick", "Arthur C. Clarke", "Ursula K. Le Guin",
    "Robert Heinlein", "Frank Herbert", "Octavia Butler", "Douglas Adams",
    "William Gibson", "Neal Stephenson", "Nora Roberts", "Danielle Steel",
    "Nicholas Sparks", "Lisa Kleypas", "Julia Quinn", "Sarah J. Maas",
    "Colleen Hoover", "Johanna Lindsey", "Eloisa James", "Jodi Picoult",
    "Ken Follett", "Hilary Mantel", "Philippa Gregory", "Anthony Doerr",
    "Erik Larson", "Diana Gabaldon", "Margaret George", "Bernard Cornwell",
    "Kate Quinn", "Ruta Sepetys",
    "Noam Chomsky", "Michel Foucault", "Judith Butler", "Pierre Bourdieu",
    "Edward Said", "Naomi Klein", "Karl Marx", "Max Weber", "Zygmunt Bauman",
    "Bruno Latour", "Sigmund Freud", "Carl Jung", "B.F. Skinner",
    "Daniel Kahneman", "Carol S. Dweck", "Erik Erikson", "Abraham Maslow",
    "Ivan Pavlov", "Albert Bandura", "Oliver Sacks", "Adam Smith",
    "John Maynard Keynes", "Milton Friedman", "Joseph E. Stiglitz",
    "Thomas Piketty", "Amartya Sen", "Friedrich Hayek", "Paul Krugman",
    "Robert J. Shiller", "Nassim Nicholas Taleb", "Howard Zinn", "Eric Hobsbawm",
    "Yuval Noah Harari", "Fernand Braudel", "Mary Beard", "David McCullough",
    "Antony Beevor", "Simon Schama", "Jared Diamond", "Niall Ferguson"
]

# %%
def extract_data_by_author(data_frame, author_list, author_column='author_name'):
    mask = data_frame[author_column].isin(author_list)
    extracted_data = data_frame[mask]
    return extracted_data

# %%
extracted_rows = extract_data_by_author(data, author_list)

extracted_rows
# Out:
#                                                       title  ratings_count  \
# book_id
# 34704992           Edgedancer (The Stormlight Archive #2.5)            632
# 2705034           Mistborn: The Final Empire (Mistborn, #1)            346
# 6656935           Mistborn: The Final Empire (Mistborn, #1)            329
# 17698536                         Steelheart (Reckoners, #1)           7783
# 17371024                    The Rithmatist (Rithmatist, #1)           2371
# ...                                                     ...            ...
# 9841                              Making Globalization Work           1523
# 13698866  The Price of Inequality: How Today's Divided S...           2191
# 16685439  The Price of Inequality: How Today's Divided S...           2769
# 316333    The Vocation Lectures: Science as a Vocation/P...            456
# 435817    The Protestant Ethic and the Spirit of Capitalism            325
#
#           author_id  average_rating  \
# book_id
# ...

# %%
author_list = [
    "J.R.R. Tolkien", "George R.R. Martin", "J.K. Rowling", "Brandon Sanderson",
    "Patrick Rothfuss", "Neil Gaiman", "Terry Pratchett", "Ursula K. Le Guin",
    "Robin Hobb", "N.K. Jemisin", "Agatha Christie", "Gillian Flynn",
    "James Patterson", "Paula Hawkins", "Lee Child", "Tana French",
    "Harlan Coben", "Raymond Chandler", "Michael Connelly", "Louise Penny",
    "Isaac Asimov", "Philip K. Dick", "Arthur C. Clarke", "Ursula K. Le Guin",
    "Robert Heinlein", "Frank Herbert", "Octavia Butler", "Douglas Adams",
    "William Gibson", "Neal Stephenson", "Nora Roberts", "Danielle Steel",
    "Nicholas Sparks", "Lisa Kleypas", "Julia Quinn", "Sarah J. Maas",
    "Colleen Hoover", "Johanna Lindsey", "Eloisa James", "Jodi Picoult",
    "Ken Follett", "Hilary Mantel", "Philippa Gregory", "Anthony Doerr",
    "Erik Larson", "Diana Gabaldon", "Margaret George", "Bernard Cornwell",
    "Kate Quinn", "Ruta Sepetys",
    "Noam Chomsky", "Michel Foucault", "Judith Butler", "Pierre Bourdieu",
    "Edward Said", "Naomi Klein", "Karl Marx", "Max Weber", "Zygmunt Bauman",
    "Bruno Latour", "Sigmund Freud", "Carl Jung", "B.F. Skinner",
    "Daniel Kahneman", "Carol S. Dweck", "Erik Erikson", "Abraham Maslow",
    "Ivan Pavlov", "Albert Bandura", "Oliver Sacks", "Adam Smith",
    "John Maynard Keynes", "Milton Friedman", "Joseph E. Stiglitz",
    "Thomas Piketty", "Amartya Sen", "Friedrich Hayek", "Paul Krugman",
    "Robert J. Shiller", "Nassim Nicholas Taleb", "Howard Zinn", "Eric Hobsbawm",
    "Yuval Noah Harari", "Fernand Braudel", "Mary Beard", "David McCullough",
    "Antony Beevor", "Simon Schama", "Jared Diamond", "Niall Ferguson"
]

extracted_rows.loc[extracted_rows['author_name'] == "George R.R. Martin"]
# Out:
#                                                       title  ratings_count  \
# book_id
# 8523840      A Game of Thrones (A Song of Ice and Fire, #1)           2796
# 21871768                       Il cavaliere dei Sette Regni            282
# 11350430  The Mystery Knight (The Tales of Dunk and Egg,...          11489
# 17393109        A Storm of Swords, Part One: Steel and Snow            222
# 768889    A Storm of Swords: Steel and Snow (A Song of I...          43058
# ...                                                     ...            ...
# 8692576                 Le Trône de fer, L'Intégrale Tome 4            213
# 6522095                                         Fevre Dream            963
# 17702284                                    Dangerous Women            778
# 11604911  A Storm of Swords: Part 1 Steel and Snow (A So...           2532
# 13330785     Choque de reyes (Canción de hielo y fuego, #2)            441
#
#           author_id  average_rating  \
# book_id
# ...

# %%
a = extracted_rows.duplicated("description")

# %%
b = extracted_rows[a]

# %%
b.loc[extracted_rows['author_name'] == "Brandon Sanderson"]
# Out:
#                                                       title  ratings_count  \
# book_id
# 623976    Alcatraz Versus the Evil Librarians (Alcatraz,...          13913
# 18957941        The Final Empire, Part 1 (Mistborn #1, 1/3)            399
# 25175964        The Final Empire, Part 3 (Mistborn #1, 3/3)            248
# 6761518                             Warbreaker, Part 2 of 3            396
# 30237009      The Way of Kings (The Stormlight Archive, #1)           3739
# 18583347                         Steelheart (Reckoners, #1)            400
# 11203858      The Way of Kings (The Stormlight Archive, #1)           1780
# 8176885                     The Hero of Ages (Mistborn, #3)           4850
# 20342545                         Steelheart (Reckoners, #1)           1013
# 25175838        The Final Empire, Part 2 (Mistborn #1, 2/3)            246
# 10063939      The Way of Kings (The Stormlight Archive, #1)            553
# ...

# %%
duplicate_rows = extracted_rows[extracted_rows.duplicated('description')]
duplicate_rows
# Out:
#                                                       title  ratings_count  \
# book_id
# 623976    Alcatraz Versus the Evil Librarians (Alcatraz,...          13913
# 18957941        The Final Empire, Part 1 (Mistborn #1, 1/3)            399
# 25175964        The Final Empire, Part 3 (Mistborn #1, 3/3)            248
# 6761518                             Warbreaker, Part 2 of 3            396
# 30237009      The Way of Kings (The Stormlight Archive, #1)           3739
# ...                                                     ...            ...
# 5494321              Mindset: The New Psychology Of Success           1897
# 1307582              Mindset: The New Psychology of Success           2693
# 16180426                           End This Depression Now!            222
# 8500417          Mistress of Rome (The Empress of Rome, #1)            370
# 16685439  The Price of Inequality: How Today's Divided S...           2769
#
#           author_id  average_rating  \
# book_id
# ...

# %%
duplicate_rows['ratings_count'] = pd.to_numeric(duplicate_rows['ratings_count'])  # Convert rating_count column to numeric type
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13624\3085910217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicate_rows['ratings_count'] = pd.to_numeric(duplicate_rows['ratings_count'])  # Convert rating_count column to numeric type

# %%
filtered_data = duplicate_rows.sort_values('ratings_count', ascending=False).drop_duplicates('description')
filtered_data
# Out:
#                                                       title  ratings_count  \
# book_id
# 3         Harry Potter and the Sorcerer's Stone (Harry P...        4765497
# 15881     Harry Potter and the Chamber of Secrets (Harry...        1821802
# 2         Harry Potter and the Order of the Phoenix (Har...        1766895
# 13496        A Game of Thrones (A Song of Ice and Fire, #1)        1359501
# 22557272                              The Girl on the Train        1076144
# ...                                                     ...            ...
# 8692576                 Le Trône de fer, L'Intégrale Tome 4            213
# 9083419   O Guia do Mochileiro das Galáxias (O mochileir...            212
# 831880                            The Left Hand Of Darkness            210
# 13405305               The Sandman, Vol. 9: The Kindly Ones            207
# 7477803              Foundation and Empire (Foundation, #2)            205
#
#           author_id  average_rating  \
# book_id
# ...

# %%
duplicate_rows.loc[extracted_rows['author_name'] == "Brandon Sanderson"]
# Out:
#                                                       title  ratings_count  \
# book_id
# 623976    Alcatraz Versus the Evil Librarians (Alcatraz,...          13913
# 18957941        The Final Empire, Part 1 (Mistborn #1, 1/3)            399
# 25175964        The Final Empire, Part 3 (Mistborn #1, 3/3)            248
# 6761518                             Warbreaker, Part 2 of 3            396
# 30237009      The Way of Kings (The Stormlight Archive, #1)           3739
# 18583347                         Steelheart (Reckoners, #1)            400
# 11203858      The Way of Kings (The Stormlight Archive, #1)           1780
# 8176885                     The Hero of Ages (Mistborn, #3)           4850
# 20342545                         Steelheart (Reckoners, #1)           1013
# 25175838        The Final Empire, Part 2 (Mistborn #1, 2/3)            246
# 10063939      The Way of Kings (The Stormlight Archive, #1)            553
# ...

# %%
filtered_data.loc[extracted_rows['author_name'] == "Brandon Sanderson"]
# Out:
#                                                       title  ratings_count  \
# book_id
# 2767793                     The Hero of Ages (Mistborn, #3)         149260
# 18739426               The Bands of Mourning (Mistborn, #6)          31236
# 18966322                      Mitosis (The Reckoners, #1.5)          17868
# 623976    Alcatraz Versus the Evil Librarians (Alcatraz,...          13913
# 20150777     Words of Radiance (The Stormlight Archive, #2)          13717
# 15704458                         Steelheart (Reckoners, #1)          12473
# 9188338       The Way of Kings (The Stormlight Archive, #1)           9026
# 11783190                    The Alloy of Law (Mistborn, #4)           6992
# 8887107                The Well of Ascension (Mistborn, #2)           5184
# 25402243                           Calamity (Reckoners, #3)           5014
# 8120570                                          Warbreaker           3946
# ...

# %%
df = extracted_rows.sort_values(by='ratings_count', ascending=False)

# %%
df = df.drop_duplicates(subset='description', keep='first')

# %%
df.loc[df["author_name"]=="Brandon Sanderson"]
# Out:
#                                                    title  ratings_count  \
# book_id
# 68428                    The Final Empire (Mistborn, #1)         216149
# 68429               The Well of Ascension (Mistborn, #2)         156471
# 7235533    The Way of Kings (The Stormlight Archive, #1)         151473
# 2767793                  The Hero of Ages (Mistborn, #3)         149260
# 68427                            Elantris (Elantris, #1)         100115
# ...                                                  ...            ...
# 28220825                  Shadows of Self (Mistborn, #5)            210
# 22673038                   Legion and the Emperor's Soul            209
# 20417243   Droga królów (Archiwum Burzowego Światła, #1)            209
# 18049581  Words of Radiance (The Stormlight Archive, #2)            206
# 28143741                  The Reckoners Series Boxed Set            204
#
#           author_id  average_rating  \
# book_id
# 68428         38550            4.43
# ...

# %%
filtered_data = filtered_data.sort_values(by='ratings_count', ascending=False)

# %%
filtered_data.loc[filtered_data["author_name"]=="Brandon Sanderson"]
# Out:
#                                                       title  ratings_count  \
# book_id
# 2767793                     The Hero of Ages (Mistborn, #3)         149260
# 18739426               The Bands of Mourning (Mistborn, #6)          31236
# 18966322                      Mitosis (The Reckoners, #1.5)          17868
# 623976    Alcatraz Versus the Evil Librarians (Alcatraz,...          13913
# 20150777     Words of Radiance (The Stormlight Archive, #2)          13717
# 15704458                         Steelheart (Reckoners, #1)          12473
# 9188338       The Way of Kings (The Stormlight Archive, #1)           9026
# 11783190                    The Alloy of Law (Mistborn, #4)           6992
# 8887107                The Well of Ascension (Mistborn, #2)           5184
# 25402243                           Calamity (Reckoners, #3)           5014
# 8120570                                          Warbreaker           3946
# ...

# %%
df.to_csv("C:/Users/DELL/Desktop/bookrecommend/selectedBooks.csv")

# %%
import pickle

# %%
import pandas as pd
df = pd.read_csv("selectedBooks.csv")

# %%
pickle.dump(df, open('selectedBooks.pkl', 'wb'))

# %%
from langdetect import detect
non_english_rows = df[df['title'].apply(lambda x: detect(x) != 'en')]

# %%
df['Language'] = df['title'].apply(lambda x: detect(x))
english_rows = df[df['Language'] == 'en']

# %%
english_rows
# Out:
#        book_id                                              title  \
# 0            3  Harry Potter and the Sorcerer's Stone (Harry P...
# 1         5907                                         The Hobbit
# 2            5  Harry Potter and the Prisoner of Azkaban (Harr...
# 3        15881  Harry Potter and the Chamber of Secrets (Harry...
# 4           34  The Fellowship of the Ring (The Lord of the Ri...
# ...        ...                                                ...
# 4313   3569016                                 The Boomerang Clue
# 4314  11813376                          Mother Earth Mother Board
# 4317  19549137            Crown of Midnight (Throne of Glass, #2)
# 4318  31847104  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 4319   9920532                                     Happy Birthday
#
#       ratings_count  author_id  average_rating  \
# 0           4765497    1077326            4.45
# 1           2099680     656983            4.25
# ...

# %%
df
# Out:
#        book_id                                              title  \
# 0            3  Harry Potter and the Sorcerer's Stone (Harry P...
# 1         5907                                         The Hobbit
# 2            5  Harry Potter and the Prisoner of Azkaban (Harr...
# 3        15881  Harry Potter and the Chamber of Secrets (Harry...
# 4           34  The Fellowship of the Ring (The Lord of the Ri...
# ...        ...                                                ...
# 4316   1206216                             The Modigliani Scandal
# 4317  19549137            Crown of Midnight (Throne of Glass, #2)
# 4318  31847104  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 4319   9920532                                     Happy Birthday
# 4320  17618007                                  Bilbo's Last Song
#
#       ratings_count  author_id  average_rating  \
# 0           4765497    1077326            4.45
# 1           2099680     656983            4.25
# ...

# %%
df[df['title'].str.contains("Harry")]
# Out:
#        book_id                                              title  \
# 0            3  Harry Potter and the Sorcerer's Stone (Harry P...
# 2            5  Harry Potter and the Prisoner of Azkaban (Harr...
# 3        15881  Harry Potter and the Chamber of Secrets (Harry...
# 5            6  Harry Potter and the Goblet of Fire (Harry Pot...
# 6       136251  Harry Potter and the Deathly Hallows (Harry Po...
# ...        ...                                                ...
# 4263    461055              The Concrete Blonde (Harry Bosch, #3)
# 4289  10355639  Harry Potter und die Heiligtümer des Todes (Ha...
# 4297  11502561                    Harry Potter a Väzeň z Azkabanu
# 4305  13563330  Harry Potter and the Sorcerer's Stone (Harry P...
# 4310  12837693                    Harry Potter et la Coupe de Feu
#
#       ratings_count  author_id  average_rating  \
# 0           4765497    1077326            4.45
# 2           1876252    1077326            4.53
# ...

# %%
english_rows = english_rows.drop('Language', axis=1)

# %%
english_rows[english_rows['title'].str.contains("Harry")]
# Out:
#        book_id                                              title  \
# 0            3  Harry Potter and the Sorcerer's Stone (Harry P...
# 2            5  Harry Potter and the Prisoner of Azkaban (Harr...
# 3        15881  Harry Potter and the Chamber of Secrets (Harry...
# 5            6  Harry Potter and the Goblet of Fire (Harry Pot...
# 6       136251  Harry Potter and the Deathly Hallows (Harry Po...
# ...        ...                                                ...
# 4194  13564685            Harry Potter and the Chamber of Secrets
# 4220  13563334  Harry Potter and the Chamber of Secrets (Harry...
# 4244   1216022  Harry Potter and the Half-Blood Prince (Harry ...
# 4263    461055              The Concrete Blonde (Harry Bosch, #3)
# 4305  13563330  Harry Potter and the Sorcerer's Stone (Harry P...
#
#       ratings_count  author_id  average_rating  \
# 0           4765497    1077326            4.45
# 2           1876252    1077326            4.53
# ...

# %%
english_rows[english_rows['title'].str.contains("Harry")]
# Out:
#        book_id                                              title  \
# 0            3  Harry Potter and the Sorcerer's Stone (Harry P...
# 2            5  Harry Potter and the Prisoner of Azkaban (Harr...
# 3        15881  Harry Potter and the Chamber of Secrets (Harry...
# 5            6  Harry Potter and the Goblet of Fire (Harry Pot...
# 6       136251  Harry Potter and the Deathly Hallows (Harry Po...
# ...        ...                                                ...
# 4194  13564685            Harry Potter and the Chamber of Secrets
# 4220  13563334  Harry Potter and the Chamber of Secrets (Harry...
# 4244   1216022  Harry Potter and the Half-Blood Prince (Harry ...
# 4263    461055              The Concrete Blonde (Harry Bosch, #3)
# 4305  13563330  Harry Potter and the Sorcerer's Stone (Harry P...
#
#       ratings_count  author_id  average_rating  \
# 0           4765497    1077326            4.45
# 2           1876252    1077326            4.53
# ...

# %%
idx = english_rows.groupby(['title', 'author_name'])['ratings_count'].idxmax()

# %%
# Filter the DataFrame based on the index
f_df = english_rows.loc[idx]
f_df[f_df["title"].str.contains("Hobbit")]
# Out:
#       book_id                                              title  \
# 113        30  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 1        5907                                         The Hobbit
# 2461  1490430  The Hobbit (Graphic Novel): An Illustrated Edi...
# 888    437049                The Hobbit, or There and Back Again
# 3695     5912                The Hobbit: Or There and Back Again
# 3396   837611                The Hobbit: or There and Back Again
#
#       ratings_count  author_id  average_rating  \
# 113           92172     656983            4.59
# 1           2099680     656983            4.25
# 2461            661     656983            4.48
# 888            5762     656983            4.25
# 3695            275     656983            4.25
# 3396            325     656983            4.25
#
#                                             description  \
# 113   This four volume, deluxe paperback boxed set c...
# 1     In a hole in the ground there lived a hobbit. ...
# ...

# %%
english_rows
# Out:
#        book_id                                              title  \
# 0            3  Harry Potter and the Sorcerer's Stone (Harry P...
# 1         5907                                         The Hobbit
# 2            5  Harry Potter and the Prisoner of Azkaban (Harr...
# 3        15881  Harry Potter and the Chamber of Secrets (Harry...
# 4           34  The Fellowship of the Ring (The Lord of the Ri...
# ...        ...                                                ...
# 4313   3569016                                 The Boomerang Clue
# 4314  11813376                          Mother Earth Mother Board
# 4317  19549137            Crown of Midnight (Throne of Glass, #2)
# 4318  31847104  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 4319   9920532                                     Happy Birthday
#
#       ratings_count  author_id  average_rating  \
# 0           4765497    1077326            4.45
# 1           2099680     656983            4.25
# ...

# %%
english_rows.to_csv("C:/Users/DELL/Desktop/bookrecommend/selectedBooks.csv")

# %%
fit = pd.read_csv("filtered_user_interactions.csv")

# %%
fit.head()
# Out:
#    user_id  book_id  is_read  rating  is_reviewed
# 0        0      948        1       5            0
# 1        0      947        1       5            1
# 2        0      946        1       5            0
# 3        0      945        1       5            0
# 4        0      944        1       5            0

# %%
filtered_fit = fit[fit['book_id'].isin(english_rows['book_id'])]

# %%
filtered_fit
# Out:
#            user_id  book_id  is_read  rating  is_reviewed
# 104              0      830        1       4            1
# 108              0      826        1       4            1
# 111              0      823        1       3            1
# 112              0      822        0       0            1
# 495              0      365        1       5            0
# ...            ...      ...      ...     ...          ...
# 118877629   442595    16307        0       0            0
# 118877788   442595    16195        0       0            0
# 118878198   442596     5364        1       4            0
# 118878647   442597     7348        0       0            0
# 118879417   442597     7332        0       0            0
#
# [433322 rows x 5 columns]

# %%
filtered_fit.to_csv("temp_interactions.csv")

# %%
import pandas as pd
new_interactions_2 = pd.read_csv("filtered_user_interactions.csv")

# %%
books_df = pd.read_csv("selectedBooks.csv")

# %%
filtered_ratings = new_interactions_2[new_interactions_2['book_id'].isin(books_df['book_id'])]

# %%
filtered_ratings.to_csv("temp_interactions_2.csv")
